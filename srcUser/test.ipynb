# %%
print('\a')

# %%
for i in range(1, 40):
    for j in range(1, 60):
        text = f"""
            <item row="{i}" column="{j}">
            <widget class="QPushButton" name="dot_unit_{i}_{j}">
            <property name="text">
                <string/>
            </property>
            </widget>
            </item>"""
        print(text)
# Out:
#             <item row="1" column="1">
#             <widget class="QPushButton" name="dot_unit_1_1">
#             <property name="text">
#                 <string/>
#             </property>
#             </widget>
#             </item>
#
#             <item row="1" column="2">
#             <widget class="QPushButton" name="dot_unit_1_2">
#             <property name="text">
#                 <string/>
#             </property>
#             </widget>
#             </item>
#
#             <item row="1" column="3">
#             <widget class="QPushButton" name="dot_unit_1_3">
#             <property name="text">
#                 <string/>
#             </property>
#             </widget>
#             </item>
#
#             <item row="1" column="4">
#             <widget class="QPushButton" name="dot_unit_1_4">
#             <property name="text">
#                 <string/>
#             </property>
#             </widget>
#             </item>
#
# ...

# %%
pip install sounddevice
# Out:
# Python(59336) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ..srcUser.data.py.dotpad_sdk import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from ..srcUser.data.py.dotpad_sdk import *
#
# ImportError: attempted relative import with no known parent package

# %%
from data.py.dotpad_sdk.dotpad import bindings,exceptions
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from data.py.dotpad_sdk.dotpad import bindings,exceptions
#
# File ~/Documents/GitHub/HCI/srcUser/data/py/dotpad_sdk/dotpad/__init__.py:1
# ----> 1 from .bindings import DotPad
#       2 from .exceptions import DotPadError, DotPadInitializationError, DotPadDisplayError
#
# File ~/Documents/GitHub/HCI/srcUser/data/py/dotpad_sdk/dotpad/bindings.py:6
#       4 # DLL 로드
#       5 try:
# ----> 6     dotpad_sdk = ctypes.WinDLL("DotPadSDK.dll")
#       7 except OSError:
#       8     raise ImportError("Could not load DotPadSDK.dll. Ensure the DLL is available.")
#
# AttributeError: module 'ctypes' has no attribute 'WinDLL'
